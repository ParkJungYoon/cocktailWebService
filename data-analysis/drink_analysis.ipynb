# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('drinks.csv')
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
cocktail = df[['country', 'spirit_servings']].sort_values(by=['spirit_servings'], ascending=False).reset_index(drop=True)
cocktail
# Out:
#                 country  spirit_servings
# 0               Grenada              438
# 1               Belarus              373
# 2                 Haiti              326
# 3    Russian Federation              326
# 4             St. Lucia              315
# ..                  ...              ...
# 188             Somalia                0
# 189            Pakistan                0
# 190              Gambia                0
# 191             Eritrea                0
# 192         Afghanistan                0
#
# [193 rows x 2 columns]

# %%
cocktail.loc[cocktail['country'] == 'South Korea']
# Out:
#          country  spirit_servings
# 129  South Korea               16

# %%
beer = df[['country', 'beer_servings']].sort_values(by=['beer_servings'], ascending=False).reset_index(drop=True)
beer
# Out:
#             country  beer_servings
# 0           Namibia            376
# 1    Czech Republic            361
# 2             Gabon            347
# 3           Germany            346
# 4         Lithuania            343
# ..              ...            ...
# 188      Mauritania              0
# 189         Somalia              0
# 190          Monaco              0
# 191        Pakistan              0
# 192     Afghanistan              0
#
# [193 rows x 2 columns]

# %%
print (beer.loc[beer['country'] == 'South Korea'])
# Out:
#         country  beer_servings
# 65  South Korea            140

# %%
wine = df[['country', 'wine_servings']].sort_values(by=['wine_servings'], ascending=False).reset_index(drop=True)
wine
# Out:
#          country  wine_servings
# 0         France            370
# 1       Portugal            339
# 2        Andorra            312
# 3    Switzerland            280
# 4        Denmark            278
# ..           ...            ...
# 188         Iran              0
# 189    Sri Lanka              0
# 190     Pakistan              0
# 191    Indonesia              0
# 192  Afghanistan              0
#
# [193 rows x 2 columns]

# %%
wine.loc[wine['country'] == 'South Korea']
# Out:
#         country  wine_servings
# 91  South Korea              9

# %%
x = ['beer', 'wine', 'cocktail']
y = [65, 91, 129]
plt.gca().invert_yaxis()
plt.plot(x, y)
plt.show()
